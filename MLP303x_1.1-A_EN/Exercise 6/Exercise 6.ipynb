# %% [markdown]
# # Decision Trees in Practice
# In this assignment we will explore various techniques for preventing overfitting in decision trees. We will extend the implementation of the binary decision trees that we implemented in the previous assignment. You will have to use your solutions from this previous assignment and extend them.
#
# In this assignment you will:
#
# * Implement binary decision trees with different early stopping methods.
# * Compare models with different stopping parameters.
# * Visualize the concept of overfitting in decision trees.
#
# Let's get started!

# %%
# Import some libs

import pandas
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Load LendingClub Dataset
# This assignment will use the [LendingClub](https://www.lendingclub.com/) dataset used in the previous two assignments.

# %%
loans_df = pandas.read_csv('/content/drive/MyDrive/FUNIX Progress/MLP303x_1.1-A_EN/data/lending-club-data.csv', low_memory=False)

# %% [markdown]
# As before, we reassign the labels to have +1 for a safe loan, and -1 for a risky (bad) loan.

# %%
# safe_loans =  1 => safe
# safe_loans = -1 => risky
loans_df['safe_loans'] = loans_df['bad_loans'].apply(lambda x : +1 if x==0 else -1)
loans_df.drop(columns=['bad_loans'])
# Out:
#              id  member_id  ...  last_major_derog_none  safe_loans
# 0       1077501    1296599  ...                      1           1
# 1       1077430    1314167  ...                      1          -1
# 2       1077175    1313524  ...                      1           1
# 3       1076863    1277178  ...                      1           1
# 4       1075269    1311441  ...                      1           1
# ...         ...        ...  ...                    ...         ...
# 122602  9856168   11708132  ...                      0          -1
# 122603  9795013   11647121  ...                      0           1
# 122604  9695736   11547808  ...                      0          -1
# 122605  9684700   11536848  ...                      1          -1
# 122606  9604874   11457002  ...                      1           1
#
# [122607 rows x 68 columns]

# %% [markdown]
# We will be using the same 4 categorical features as in the previous assignment:
# 1. grade of the loan
# 2. the length of the loan term
# 3. the home ownership status: own, mortgage, rent
# 4. number of years of employment.
#
# In the dataset, each of these features is a categorical feature. Since we are building a binary decision tree, we will have to convert this to binary data in a subsequent section using 1-hot encoding.

# %%
features = ['grade',              # grade of the loan
            'term',               # the term of the loan
            'home_ownership',     # home_ownership status: own, mortgage or rent
            'emp_length',         # number of years of employment
           ]
target = 'safe_loans'
loans_df = loans_df[features + [target]]

# %% [markdown]
# ## Subsample dataset to make sure classes are balanced
# Just as we did in the previous assignment, we will undersample the larger class (safe loans) in order to balance out our dataset. This means we are throwing away many data points. We used `seed = 1` so everyone gets the same results.

# %%
safe_loans_raw = loans_df[loans_df[target] == +1]
risky_loans_raw = loans_df[loans_df[target] == -1]

# Since there are fewer risky loans than safe loans, find the ratio of the sizes
# and use that percentage to undersample the safe loans.
percentage = risky_loans_raw.shape[0]/safe_loans_raw.shape[0]

risky_loans = risky_loans_raw
safe_loans = safe_loans_raw.sample(frac=percentage, random_state=1)

# Append the risky_loans with the downsampled version of safe_loans
loans_data = risky_loans.append(safe_loans)

print ("Percentage of safe loans                 : {}".format(safe_loans.shape[0] / loans_data.shape[0]))
print ("Percentage of risky loans                : {}".format(risky_loans.shape[0] / loans_data.shape[0]))
print ("Total number of loans in our new dataset : {}".format(loans_data.shape[0]))
# Out:
# Percentage of safe loans                 : 0.5
# Percentage of risky loans                : 0.5
# Total number of loans in our new dataset : 46300

# %% [markdown]
# **Note:** There are many approaches for dealing with imbalanced data, including some where we modify the learning algorithm. These approaches are beyond the scope of this course, but some of them are reviewed in this [paper](http://ieeexplore.ieee.org/xpl/login.jsp?tp=&arnumber=5128907&url=http%3A%2F%2Fieeexplore.ieee.org%2Fiel5%2F69%2F5173046%2F05128907.pdf%3Farnumber%3D5128907 ). For this assignment, we use the simplest possible approach, where we subsample the overly represented class to get a more balanced dataset. In general, and especially when the data is highly imbalanced, we recommend using more advanced methods.

# %% [markdown]
# ## Transform categorical data into binary features
# In this assignment, we will implement **binary decision trees** (decision trees for binary features, a specific case of categorical variables taking on two values, e.g., true/false). Since all of our features are currently categorical features, we want to turn them into binary features.
#
# For instance, the **home_ownership** feature represents the home ownership status of the loanee, which is either `own`, `mortgage` or `rent`. For example, if a data point has the feature
# ```
#    {'home_ownership': 'RENT'}
# ```
# we want to turn this into three features:
# ```
#  {
#    'home_ownership = OWN'      : 0,
#    'home_ownership = MORTGAGE' : 0,
#    'home_ownership = RENT'     : 1
#  }
# ```

# %%
print(loans_data.dtypes)
categorical_variables = list(loans_data.select_dtypes(include=['object']).columns)
print(categorical_variables)

one_hot_data = pandas.get_dummies(loans_data[categorical_variables], prefix=categorical_variables)
# need to add inplace in oreder to drop columns.
loans_data.drop(columns=categorical_variables, axis=1, inplace=True)
loans_data = pandas.concat([loans_data, one_hot_data], axis=1)

print(loans_data['grade_A'].values.sum())
print(loans_data.dtypes)
# Out:
# grade             object
# term              object
# home_ownership    object
# emp_length        object
# safe_loans         int64
# dtype: object
# ['grade', 'term', 'home_ownership', 'emp_length']
# 6508
# safe_loans                 int64
# grade_A                    uint8
# grade_B                    uint8
# grade_C                    uint8
# grade_D                    uint8
# grade_E                    uint8
# grade_F                    uint8
# grade_G                    uint8
# term_ 36 months            uint8
# term_ 60 months            uint8
# home_ownership_MORTGAGE    uint8
# home_ownership_OTHER       uint8
# home_ownership_OWN         uint8
# home_ownership_RENT        uint8
# emp_length_1 year          uint8
# emp_length_10+ years       uint8
# emp_length_2 years         uint8
# emp_length_3 years         uint8
# emp_length_4 years         uint8
# emp_length_5 years         uint8
# emp_length_6 years         uint8
# emp_length_7 years         uint8
# emp_length_8 years         uint8
# emp_length_9 years         uint8
# emp_length_< 1 year        uint8
# dtype: object

# %% [markdown]
# ## Train-test split
#
# We split the data into a train test split with 80% of the data in the training set and 20% of the data in the test set. We use `seed=1` so that everyone gets the same result.

# %%
np.random.seed(1)

train_data, validation_data = train_test_split(loans_data, test_size=0.2)

# %% [markdown]
# # Early stopping methods for decision trees
# In this section, we will extend the **binary tree implementation** from the previous assignment in order to handle some early stopping conditions. Recall the 3 early stopping methods that were discussed in lecture:
#
# 1. Reached a **maximum depth**. (set by parameter `max_depth`).
# 2. Reached a **minimum node size**. (set by parameter `min_node_size`).
# 3. Don't split if the **gain in error reduction** is too small. (set by parameter `min_error_reduction`).
#
# For the rest of this assignment, we will refer to these three as **early stopping conditions 1, 2, and 3**.
#
# ## Early stopping condition 1: Maximum depth
#
# Recall that we already implemented the maximum depth stopping condition in the previous assignment. In this assignment, we will experiment with this condition a bit more and also write code to implement the 2nd and 3rd early stopping conditions.
#
# We will be reusing code from the previous assignment and then building upon this.  We will **alert you** when you reach a function that was part of the previous assignment so that you can simply copy and past your previous code.
#
# ## Early stopping condition 2: Minimum node size
#
# The function **reached_minimum_node_size** takes 2 arguments:
#
# 1. The `data` (from a node)
# 2. The minimum number of data points that a node is allowed to split on, `min_node_size`.
#
# This function simply calculates whether the number of data points at a given node is less than or equal to the specified minimum node size. This function will be used to detect this early stopping condition in the **decision_tree_create** function.
#
# Fill in the parts of the function below where you find `## YOUR CODE HERE`.  There is **one** instance in the function below.

# %%
def reached_minimum_node_size(data, min_node_size):
    # Return True if the number of data points is less than or equal to the minimum node size.
    return (len(data) <= min_node_size)

# %% [markdown]
# **Quiz Question:** Given an intermediate node with 6 safe loans and 3 risky loans, if the `min_node_size` parameter is 10, what should the tree learning algorithm do next?
# <br>
# **Your answer:** Early Stop

# %% [markdown]
# ## Early stopping condition 3: Minimum gain in error reduction
# The function **error_reduction** takes 2 arguments:
#
# 1. The error **before** a split, `error_before_split`.
# 2. The error **after** a split, `error_after_split`.
#
# This function computes the gain in error reduction, i.e., the difference between the error before the split and that after the split. This function will be used to detect this early stopping condition in the **decision_tree_create** function.
#
# Fill in the parts of the function below where you find `## YOUR CODE HERE`.  There is **one** instance in the function below.

# %%
def error_reduction(error_before_split, error_after_split):
    # Return the error before the split minus the error after the split.
    return error_before_split - error_after_split

# %% [markdown]
# **Quiz Question:** Assume an intermediate node has 6 safe loans and 3 risky loans.  For each of 4 possible features to split on, the error reduction is 0.0, 0.05, 0.1, and 0.14, respectively. If the **minimum gain in error reduction** parameter is set to 0.2, what should the tree learning algorithm do next?
# <br>
# **Your answer:** Early Stop

# %% [markdown]
# ## Grabbing binary decision tree helper functions from past assignment
# Recall from the previous assignment that we wrote a function `intermediate_node_num_mistakes` that calculates the number of **misclassified examples** when predicting the **majority class**. This is used to help determine which feature is best to split on at a given node of the tree.
#
# **Please copy and paste your code for `intermediate_node_num_mistakes` here**.

# %%
def intermediate_node_num_mistakes(labels_in_node):
    # Corner case: If labels_in_node is empty, return 0
    if(len(labels_in_node) == 0):
        return 0
    
    # Count the number of 1's (safe loans)
    safe_loans = sum([1 if i == 1 else 0 for i in labels_in_node])

    
    # Count the number of -1's (risky loans)
    risky_loans = sum([1 if i == -1 else 0 for i in labels_in_node]) 

                
    # Return the number of mistakes that the majority classifier makes.
    label = 1 if sum(labels_in_node) > 0 else -1
    
    if label == 1:
        return risky_loans
    else:
        return safe_loans

# %% [markdown]
# We then wrote a function `best_splitting_feature` that finds the best feature to split on given the data and a list of features to consider.
#
# **Please copy and paste your `best_splitting_feature` code here**.

# %%
def best_splitting_feature(data, features, target):
    
    best_feature = None # Keep track of the best feature 
    best_error = 10     # Keep track of the best error so far 
    # Note: Since error is always <= 1, we should intialize it with something larger than 1.

    # Convert to float to make sure error gets computed correctly.
    num_data_points = float(len(data))  
    
    # Loop through each feature to consider splitting on that feature
    for feature in features:
        
        # The left split will have all data points where the feature value is 0
        left_split = data[data[feature] == 0]
        
        # The right split will have all data points where the feature value is 1
        right_split =  data[data[feature] == 1]

            
        # Calculate the number of misclassified examples in the left split.
        # Remember that we implemented a function for this! (It was called intermediate_node_num_mistakes)
        left_mistakes =  intermediate_node_num_mistakes(left_split['safe_loans'])   
  

        # Calculate the number of misclassified examples in the right split.
        right_mistakes = intermediate_node_num_mistakes(right_split['safe_loans'])

            
        # Compute the classification error of this split.
        # Error = (# of mistakes (left) + # of mistakes (right)) / (# of data points)
        ## YOUR CODE HERE
        error = (left_mistakes + right_mistakes) / data.shape[0]

        # If this is the best error we have found so far, store the feature as best_feature and the error as best_error
        ## YOUR CODE HERE
        if error < best_error:
          best_error = error
          best_feature = feature
    
    return best_feature # Return the best feature we found

# %% [markdown]
# Finally, recall the function `create_leaf` from the previous assignment, which creates a leaf node given a set of target values.
#
# **Please copy and paste your `create_leaf` code here**.

# %%
def create_leaf(target_values):
    
    # Create a leaf node
    leaf = {'splitting_feature' : None,
            'left' : None,
            'right' : None,
            'is_leaf': True
            }
    
    # Count the number of data points that are +1 and -1 in this node.
    num_ones = target_values[target_values == +1].shape[0]
    num_minus_ones = target_values[target_values == -1].shape[0]
    
    # For the leaf node, set the prediction to be the majority class.
    # Store the predicted class (1 or -1) in leaf['prediction']
    if(num_ones > num_minus_ones):
      leaf['prediction'] = 1
    else:
      leaf['prediction'] = -1
        
    # Return the leaf node        
    return leaf

# %% [markdown]
# ## Incorporating new early stopping conditions in binary decision tree implementation

# %% [markdown]
# Now, you will implement a function that builds a decision tree handling the three early stopping conditions described in this assignment.  In particular, you will write code to detect early stopping conditions 2 and 3.  You implemented above the functions needed to detect these conditions.  The 1st early stopping condition, **max_depth**, was implemented in the previous assigment and you will not need to reimplement this.  In addition to these early stopping conditions, the typical stopping conditions of having no mistakes or no more features to split on (which we denote by "stopping conditions" 1 and 2) are also included as in the previous assignment.
#
# **Implementing early stopping condition 2: minimum node size:**
#
# * **Step 1:** Use the function **reached_minimum_node_size** that you implemented earlier to write an if condition to detect whether we have hit the base case, i.e., the node does not have enough data points and should be turned into a leaf. Don't forget to use the `min_node_size` argument.
# * **Step 2:** Return a leaf. This line of code should be the same as the other (pre-implemented) stopping conditions.
#
#
# **Implementing early stopping condition 3: minimum error reduction:**
#
# **Note:** This has to come after finding the best splitting feature so we can calculate the error after splitting in order to calculate the error reduction.
#
# * **Step 1:** Calculate the **classification error before splitting**.  Recall that classification error is defined as:
#
# $$
# \text{classification error} = \frac{\text{# mistakes}}{\text{# total examples}}
# $$
# * **Step 2:** Calculate the **classification error after splitting**. This requires calculating the number of mistakes in the left and right splits, and then dividing by the total number of examples.
# * **Step 3:** Use the function **error_reduction** to that you implemented earlier to write an if condition to detect whether  the reduction in error is less than the constant provided (`min_error_reduction`). Don't forget to use that argument.
# * **Step 4:** Return a leaf. This line of code should be the same as the other (pre-implemented) stopping conditions.
#
# Fill in the places where you find `## YOUR CODE HERE`. There are **seven** places in this function for you to fill in.

# %%
def decision_tree_create(data, features, target, current_depth = 0, 
                         max_depth = 10, min_node_size=1, 
                         min_error_reduction=0.0):
    remaining_features = features[:] # Make a copy of the features.
    
    target_values = data[target]
    print("--------------------------------------------------------------------")
    print("Subtree, depth = %s (%s data points)." % (current_depth, target_values.shape[0]))
    

    # Stopping condition 1
    # (Check if there are mistakes at current node.
    # Recall you wrote a function intermediate_node_num_mistakes to compute this.)
    if (intermediate_node_num_mistakes(target_values) == 0):
        print("Stopping condition 1 reached.")     
        # If not mistakes at current node, make current node a leaf node
        return create_leaf(target_values)
    
    # Stopping condition 2 (check if there are remaining features to consider splitting on)
    if (len(remaining_features) == []):
        print("Stopping condition 2 reached.")    
        # If there are no remaining features to consider, make current node a leaf node
        return create_leaf(target_values)    
    
    # Additional stopping condition (limit tree depth)
    if (current_depth >= max_depth): 
        print("Reached maximum depth. Stopping for now.")
        # If the max tree depth has been reached, make current node a leaf node
        return create_leaf(target_values)
    
    # Early stopping condition 2: Reached the minimum node size.
    # If the number of data points is less than or equal to the minimum size, return a leaf.
    if reached_minimum_node_size(data, min_node_size):
        print("Early stopping condition 2 reached. Reached minimum node size.")
        return create_leaf(target_values)

    # Find the best splitting feature (recall the function best_splitting_feature implemented above)
    splitting_feature = best_splitting_feature(data, features, target)
    
    # Split on the best feature that we found. 
    left_split = data[data[splitting_feature] == 0]
    right_split = data[data[splitting_feature] == 1]
    
    # Early stopping condition 3: Minimum error reduction
    # Calculate the error before splitting (number of misclassified examples 
    # divided by the total number of examples)
    error_before_split = intermediate_node_num_mistakes(target_values) / float(len(data))
    
    # Calculate the error after splitting (number of misclassified examples 
    # in both groups divided by the total number of examples)
    left_mistakes = intermediate_node_num_mistakes(left_split[target]) / float(len(data))
    right_mistakes = intermediate_node_num_mistakes(right_split[target]) / float(len(data))
    error_after_split = (left_mistakes + right_mistakes) / float(len(data))
    
    # If the error reduction is LESS THAN OR EQUAL TO min_error_reduction, return a leaf.
    if error_reduction(error_before_split, error_after_split) <= min_error_reduction:
        print("Early stopping condition 3 reached. Minimum error reduction.")
        return create_leaf(target_values)
    
    remaining_features.remove(splitting_feature)
    print("Split on feature %s. (%s, %s)" % (\
                      splitting_feature, len(left_split), len(right_split)))
        
    # Repeat (recurse) on left and right subtrees
    left_tree = decision_tree_create(left_split, remaining_features, target, current_depth + 1, max_depth)        
    ## YOUR CODE HERE
    right_tree = decision_tree_create(right_split, remaining_features, target, current_depth + 1, max_depth)        

    return {'is_leaf'          : False, 
            'prediction'       : None,
            'splitting_feature': splitting_feature,
            'left'             : left_tree, 
            'right'            : right_tree}

# %% [markdown]
# Here is a function to count the nodes in your tree:

# %%
def count_nodes(tree):
    if tree['is_leaf']:
        return 1
    return 1 + count_nodes(tree['left']) + count_nodes(tree['right'])

# %% [markdown]
# Run the following test code to check your implementation. Make sure you get **'Test passed'** before proceeding.

# %%
features = list(loans_data.columns)
features.remove('safe_loans')

small_decision_tree = decision_tree_create(train_data, features, 'safe_loans', max_depth = 2, 
                                           min_node_size = 10, min_error_reduction=0.0)
if count_nodes(small_decision_tree) == 7:
    print ('Test passed!')
else:
    print ('Test failed... try again!')
    print ('Number of nodes found                :', count_nodes(small_decision_tree))
    print ('Number of nodes that should be there : 7')
# Out:
# --------------------------------------------------------------------
# Subtree, depth = 0 (37040 data points).
# Split on feature term_ 36 months. (9419, 27621)
# --------------------------------------------------------------------
# Subtree, depth = 1 (9419 data points).
# Split on feature grade_A. (9293, 126)
# --------------------------------------------------------------------
# Subtree, depth = 2 (9293 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 2 (126 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 1 (27621 data points).
# Split on feature grade_D. (22974, 4647)
# --------------------------------------------------------------------
# Subtree, depth = 2 (22974 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 2 (4647 data points).
# Reached maximum depth. Stopping for now.
# Test passed!

# %% [markdown]
# ## Build a tree!
#
# Now that your code is working, we will train a tree model on the **train_data** with
# * `max_depth = 6`
# * `min_node_size = 100`,
# * `min_error_reduction = 0.0`
#
# **Warning**: This code block may take a minute to learn.

# %%
my_decision_tree_new = decision_tree_create(train_data, features, 'safe_loans', max_depth = 6, 
                                min_node_size = 100, min_error_reduction=0.0)
# Out:
# --------------------------------------------------------------------
# Subtree, depth = 0 (37040 data points).
# Split on feature term_ 36 months. (9419, 27621)
# --------------------------------------------------------------------
# Subtree, depth = 1 (9419 data points).
# Split on feature grade_A. (9293, 126)
# --------------------------------------------------------------------
# Subtree, depth = 2 (9293 data points).
# Split on feature grade_B. (8227, 1066)
# --------------------------------------------------------------------
# Subtree, depth = 3 (8227 data points).
# Split on feature grade_C. (5974, 2253)
# --------------------------------------------------------------------
# Subtree, depth = 4 (5974 data points).
# Split on feature grade_D. (3891, 2083)
# --------------------------------------------------------------------
# Subtree, depth = 5 (3891 data points).
# Split on feature grade_E. (1721, 2170)
# --------------------------------------------------------------------
# Subtree, depth = 6 (1721 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (2170 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 5 (2083 data points).
# Split on feature grade_E. (2083, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (2083 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 4 (2253 data points).
# Split on feature grade_D. (2253, 0)
# --------------------------------------------------------------------
# Subtree, depth = 5 (2253 data points).
# Split on feature grade_E. (2253, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (2253 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 5 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 3 (1066 data points).
# Split on feature emp_length_5 years. (986, 80)
# --------------------------------------------------------------------
# Subtree, depth = 4 (986 data points).
# Split on feature emp_length_3 years. (900, 86)
# --------------------------------------------------------------------
# Subtree, depth = 5 (900 data points).
# Split on feature grade_C. (900, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (900 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 5 (86 data points).
# Split on feature home_ownership_MORTGAGE. (39, 47)
# --------------------------------------------------------------------
# Subtree, depth = 6 (39 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (47 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 4 (80 data points).
# Split on feature home_ownership_RENT. (58, 22)
# --------------------------------------------------------------------
# Subtree, depth = 5 (58 data points).
# Split on feature grade_C. (58, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (58 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 5 (22 data points).
# Split on feature grade_C. (22, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (22 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 2 (126 data points).
# Split on feature home_ownership_MORTGAGE. (36, 90)
# --------------------------------------------------------------------
# Subtree, depth = 3 (36 data points).
# Split on feature emp_length_< 1 year. (26, 10)
# --------------------------------------------------------------------
# Subtree, depth = 4 (26 data points).
# Split on feature emp_length_2 years. (23, 3)
# --------------------------------------------------------------------
# Subtree, depth = 5 (23 data points).
# Split on feature emp_length_5 years. (20, 3)
# --------------------------------------------------------------------
# Subtree, depth = 6 (20 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (3 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 5 (3 data points).
# Split on feature grade_B. (3, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (3 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 4 (10 data points).
# Split on feature grade_B. (10, 0)
# --------------------------------------------------------------------
# Subtree, depth = 5 (10 data points).
# Split on feature grade_C. (10, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (10 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 5 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 3 (90 data points).
# Split on feature grade_B. (90, 0)
# --------------------------------------------------------------------
# Subtree, depth = 4 (90 data points).
# Split on feature grade_C. (90, 0)
# --------------------------------------------------------------------
# Subtree, depth = 5 (90 data points).
# Split on feature grade_D. (90, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (90 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 5 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 4 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 1 (27621 data points).
# Split on feature grade_D. (22974, 4647)
# --------------------------------------------------------------------
# Subtree, depth = 2 (22974 data points).
# Split on feature grade_E. (21728, 1246)
# --------------------------------------------------------------------
# Subtree, depth = 3 (21728 data points).
# Split on feature grade_C. (14570, 7158)
# --------------------------------------------------------------------
# Subtree, depth = 4 (14570 data points).
# Split on feature grade_F. (14207, 363)
# --------------------------------------------------------------------
# Subtree, depth = 5 (14207 data points).
# Split on feature grade_G. (14097, 110)
# --------------------------------------------------------------------
# Subtree, depth = 6 (14097 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (110 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 5 (363 data points).
# Split on feature grade_A. (363, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (363 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 4 (7158 data points).
# Split on feature home_ownership_RENT. (3458, 3700)
# --------------------------------------------------------------------
# Subtree, depth = 5 (3458 data points).
# Split on feature emp_length_< 1 year. (3257, 201)
# --------------------------------------------------------------------
# Subtree, depth = 6 (3257 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (201 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 5 (3700 data points).
# Split on feature emp_length_2 years. (3279, 421)
# --------------------------------------------------------------------
# Subtree, depth = 6 (3279 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (421 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 3 (1246 data points).
# Split on feature grade_A. (1246, 0)
# --------------------------------------------------------------------
# Subtree, depth = 4 (1246 data points).
# Split on feature grade_B. (1246, 0)
# --------------------------------------------------------------------
# Subtree, depth = 5 (1246 data points).
# Split on feature grade_C. (1246, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (1246 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 5 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 4 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 2 (4647 data points).
# Split on feature grade_A. (4647, 0)
# --------------------------------------------------------------------
# Subtree, depth = 3 (4647 data points).
# Split on feature grade_B. (4647, 0)
# --------------------------------------------------------------------
# Subtree, depth = 4 (4647 data points).
# Split on feature grade_C. (4647, 0)
# --------------------------------------------------------------------
# Subtree, depth = 5 (4647 data points).
# Split on feature grade_E. (4647, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (4647 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 5 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 4 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 3 (0 data points).
# Stopping condition 1 reached.

# %% [markdown]
# Let's now train a tree model **ignoring early stopping conditions 2 and 3** so that we get the same tree as in the previous assignment.  To ignore these conditions, we set `min_node_size=0` and `min_error_reduction=-1` (a negative value).

# %%
my_decision_tree_old = decision_tree_create(train_data, features, 'safe_loans', max_depth = 6, 
                                min_node_size = 0, min_error_reduction=-1)
# Out:
# --------------------------------------------------------------------
# Subtree, depth = 0 (37040 data points).
# Split on feature term_ 36 months. (9419, 27621)
# --------------------------------------------------------------------
# Subtree, depth = 1 (9419 data points).
# Split on feature grade_A. (9293, 126)
# --------------------------------------------------------------------
# Subtree, depth = 2 (9293 data points).
# Split on feature grade_B. (8227, 1066)
# --------------------------------------------------------------------
# Subtree, depth = 3 (8227 data points).
# Split on feature grade_C. (5974, 2253)
# --------------------------------------------------------------------
# Subtree, depth = 4 (5974 data points).
# Split on feature grade_D. (3891, 2083)
# --------------------------------------------------------------------
# Subtree, depth = 5 (3891 data points).
# Split on feature grade_E. (1721, 2170)
# --------------------------------------------------------------------
# Subtree, depth = 6 (1721 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (2170 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 5 (2083 data points).
# Split on feature grade_E. (2083, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (2083 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 4 (2253 data points).
# Split on feature grade_D. (2253, 0)
# --------------------------------------------------------------------
# Subtree, depth = 5 (2253 data points).
# Split on feature grade_E. (2253, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (2253 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 5 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 3 (1066 data points).
# Split on feature emp_length_5 years. (986, 80)
# --------------------------------------------------------------------
# Subtree, depth = 4 (986 data points).
# Split on feature emp_length_3 years. (900, 86)
# --------------------------------------------------------------------
# Subtree, depth = 5 (900 data points).
# Split on feature grade_C. (900, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (900 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 5 (86 data points).
# Split on feature home_ownership_MORTGAGE. (39, 47)
# --------------------------------------------------------------------
# Subtree, depth = 6 (39 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (47 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 4 (80 data points).
# Split on feature home_ownership_RENT. (58, 22)
# --------------------------------------------------------------------
# Subtree, depth = 5 (58 data points).
# Split on feature grade_C. (58, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (58 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 5 (22 data points).
# Split on feature grade_C. (22, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (22 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 2 (126 data points).
# Split on feature home_ownership_MORTGAGE. (36, 90)
# --------------------------------------------------------------------
# Subtree, depth = 3 (36 data points).
# Split on feature emp_length_< 1 year. (26, 10)
# --------------------------------------------------------------------
# Subtree, depth = 4 (26 data points).
# Split on feature emp_length_2 years. (23, 3)
# --------------------------------------------------------------------
# Subtree, depth = 5 (23 data points).
# Split on feature emp_length_5 years. (20, 3)
# --------------------------------------------------------------------
# Subtree, depth = 6 (20 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (3 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 5 (3 data points).
# Split on feature grade_B. (3, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (3 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 4 (10 data points).
# Split on feature grade_B. (10, 0)
# --------------------------------------------------------------------
# Subtree, depth = 5 (10 data points).
# Split on feature grade_C. (10, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (10 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 5 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 3 (90 data points).
# Split on feature grade_B. (90, 0)
# --------------------------------------------------------------------
# Subtree, depth = 4 (90 data points).
# Split on feature grade_C. (90, 0)
# --------------------------------------------------------------------
# Subtree, depth = 5 (90 data points).
# Split on feature grade_D. (90, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (90 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 5 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 4 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 1 (27621 data points).
# Split on feature grade_D. (22974, 4647)
# --------------------------------------------------------------------
# Subtree, depth = 2 (22974 data points).
# Split on feature grade_E. (21728, 1246)
# --------------------------------------------------------------------
# Subtree, depth = 3 (21728 data points).
# Split on feature grade_C. (14570, 7158)
# --------------------------------------------------------------------
# Subtree, depth = 4 (14570 data points).
# Split on feature grade_F. (14207, 363)
# --------------------------------------------------------------------
# Subtree, depth = 5 (14207 data points).
# Split on feature grade_G. (14097, 110)
# --------------------------------------------------------------------
# Subtree, depth = 6 (14097 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (110 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 5 (363 data points).
# Split on feature grade_A. (363, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (363 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 4 (7158 data points).
# Split on feature home_ownership_RENT. (3458, 3700)
# --------------------------------------------------------------------
# Subtree, depth = 5 (3458 data points).
# Split on feature emp_length_< 1 year. (3257, 201)
# --------------------------------------------------------------------
# Subtree, depth = 6 (3257 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (201 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 5 (3700 data points).
# Split on feature emp_length_2 years. (3279, 421)
# --------------------------------------------------------------------
# Subtree, depth = 6 (3279 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (421 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 3 (1246 data points).
# Split on feature grade_A. (1246, 0)
# --------------------------------------------------------------------
# Subtree, depth = 4 (1246 data points).
# Split on feature grade_B. (1246, 0)
# --------------------------------------------------------------------
# Subtree, depth = 5 (1246 data points).
# Split on feature grade_C. (1246, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (1246 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 5 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 4 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 2 (4647 data points).
# Split on feature grade_A. (4647, 0)
# --------------------------------------------------------------------
# Subtree, depth = 3 (4647 data points).
# Split on feature grade_B. (4647, 0)
# --------------------------------------------------------------------
# Subtree, depth = 4 (4647 data points).
# Split on feature grade_C. (4647, 0)
# --------------------------------------------------------------------
# Subtree, depth = 5 (4647 data points).
# Split on feature grade_E. (4647, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (4647 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 5 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 4 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 3 (0 data points).
# Stopping condition 1 reached.

# %% [markdown]
# ## Making predictions
# Recall that in the previous assignment you implemented a function `classify` to classify a new point `x` using a given `tree`.
#
# **Please copy and paste your `classify` code here**.

# %%
def classify(tree, x, annotate = False):   
    # if the node is a leaf node.
    if tree['is_leaf']:
        if annotate: 
            print ("At leaf, predicting %s" % tree['prediction'])
        return tree['prediction'] 
    else:
        # split on feature.
        split_feature_value = x[tree['splitting_feature']]
        if annotate: 
            print ("Split on %s = %s" % (tree['splitting_feature'], split_feature_value))
        if split_feature_value == 0:
            return classify(tree['left'], x, annotate)
        else:
            return classify(tree['right'], x, annotate)

# %% [markdown]
# Now, let's consider the first example of the validation set and see what the `my_decision_tree_new` model predicts for this data point.

# %%
validation_data.iloc[0]
# Out:
# safe_loans                -1
# grade_A                    0
# grade_B                    0
# grade_C                    0
# grade_D                    0
# grade_E                    1
# grade_F                    0
# grade_G                    0
# term_ 36 months            1
# term_ 60 months            0
# home_ownership_MORTGAGE    0
# home_ownership_OTHER       0
# home_ownership_OWN         0
# home_ownership_RENT        1
# emp_length_1 year          0
# emp_length_10+ years       1
# emp_length_2 years         0
# emp_length_3 years         0
# emp_length_4 years         0
# emp_length_5 years         0
# emp_length_6 years         0
# emp_length_7 years         0
# emp_length_8 years         0
# emp_length_9 years         0
# emp_length_< 1 year        0
# Name: 121355, dtype: int64

# %%
print('Predicted class: %s ' % classify(my_decision_tree_new, validation_data.iloc[0]))
# Out:
# Predicted class: -1

# %% [markdown]
# Let's add some annotations to our prediction to see what the prediction path was that lead to this predicted class:

# %%
classify(my_decision_tree_new, validation_data.iloc[0], annotate = True)
# Out:
# Split on term_ 36 months = 1
# Split on grade_D = 0
# Split on grade_E = 1
# Split on grade_A = 0
# Split on grade_B = 0
# Split on grade_C = 0
# At leaf, predicting -1
# -1

# %% [markdown]
# Let's now recall the prediction path for the decision tree learned in the previous assignment, which we recreated here as `my_decision_tree_old`.

# %%
classify(my_decision_tree_old, validation_data.iloc[0], annotate = True)
# Out:
# Split on term_ 36 months = 1
# Split on grade_D = 0
# Split on grade_E = 1
# Split on grade_A = 0
# Split on grade_B = 0
# Split on grade_C = 0
# At leaf, predicting -1
# -1

# %% [markdown]
# **Quiz Question:** For `my_decision_tree_new` trained with `max_depth = 6`, `min_node_size = 100`, `min_error_reduction=0.0`, is the prediction path for `validation_set[0]` shorter, longer, or the same as for `my_decision_tree_old` that ignored the early stopping conditions 2 and 3?
# <br>
# **Your answer:**

# %% [markdown]
# **Quiz Question:** For `my_decision_tree_new` trained with `max_depth = 6`, `min_node_size = 100`, `min_error_reduction=0.0`, is the prediction path for **any point** always shorter, always longer, always the same, shorter or the same, or longer or the same as for `my_decision_tree_old` that ignored the early stopping conditions 2 and 3?
# <br>
# **Your answer:**

# %% [markdown]
# **Quiz Question:** For a tree trained on **any** dataset using `max_depth = 6`, `min_node_size = 100`, `min_error_reduction=0.0`, what is the maximum number of splits encountered while making a single prediction?
# <br>
# **Your answer:**

# %% [markdown]
# ## Evaluating the model
# Now let us evaluate the model that we have trained. You implemented this evaluation in the function `evaluate_classification_error` from the previous assignment.
#
# **Please copy and paste your `evaluate_classification_error` code here**.

# %%
def evaluate_classification_error(tree, data, target):
    # Apply the classify(tree, x) to each row in your data
    prediction = []
    for i, row in data.iterrows():
        prediction.append(classify(tree, row))
    
    # Once you've made the predictions, calculate the classification error and return it
    ## YOUR CODE HERE
    right = data[data['safe_loans'] == prediction]
    return 1 - len(right)*1.0/len(data)

# %% [markdown]
# Now, let's use this function to evaluate the classification error of `my_decision_tree_new` on the **validation_set**.

# %%
evaluate_classification_error(my_decision_tree_new, validation_data, target)
# Out:
# 0.3827213822894169

# %% [markdown]
# Now, evaluate the validation error using `my_decision_tree_old`.

# %%
evaluate_classification_error(my_decision_tree_old, validation_data, target)
# Out:
# 0.3827213822894169

# %% [markdown]
# **Quiz Question:** Is the validation error of the new decision tree (using early stopping conditions 2 and 3) lower than, higher than, or the same as that of the old decision tree from the previous assignment?
# <br>
# **Your answer:**

# %% [markdown]
# # Exploring the effect of max_depth
#
# We will compare three models trained with different values of the stopping criterion. We intentionally picked models at the extreme ends (**too small**, **just right**, and **too large**).
#
# Train three models with these parameters:
#
# 1. **model_1**: max_depth = 2 (too small)
# 2. **model_2**: max_depth = 6 (just right)
# 3. **model_3**: max_depth = 14 (may be too large)
#
# For each of these three, we set `min_node_size = 0` and `min_error_reduction = -1`.
#
# ** Note:** Each tree can take up to a few minutes to train. In particular, `model_3` will probably take the longest to train.

# %%
# YOUR CODE HERE
model_1 = decision_tree_create(train_data, features, 'safe_loans', max_depth = 2, 
                                min_node_size = 0, min_error_reduction=-1)
model_2 = decision_tree_create(train_data, features, 'safe_loans', max_depth = 6, 
                                min_node_size = 0, min_error_reduction=-1)
model_3 = decision_tree_create(train_data, features, 'safe_loans', max_depth = 14, 
                                min_node_size = 0, min_error_reduction=-1)
# Out:
# --------------------------------------------------------------------
# Subtree, depth = 0 (37040 data points).
# Split on feature term_ 36 months. (9419, 27621)
# --------------------------------------------------------------------
# Subtree, depth = 1 (9419 data points).
# Split on feature grade_A. (9293, 126)
# --------------------------------------------------------------------
# Subtree, depth = 2 (9293 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 2 (126 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 1 (27621 data points).
# Split on feature grade_D. (22974, 4647)
# --------------------------------------------------------------------
# Subtree, depth = 2 (22974 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 2 (4647 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 0 (37040 data points).
# Split on feature term_ 36 months. (9419, 27621)
# --------------------------------------------------------------------
# Subtree, depth = 1 (9419 data points).
# Split on feature grade_A. (9293, 126)
# --------------------------------------------------------------------
# Subtree, depth = 2 (9293 data points).
# Split on feature grade_B. (8227, 1066)
# --------------------------------------------------------------------
# Subtree, depth = 3 (8227 data points).
# Split on feature grade_C. (5974, 2253)
# --------------------------------------------------------------------
# Subtree, depth = 4 (5974 data points).
# Split on feature grade_D. (3891, 2083)
# --------------------------------------------------------------------
# Subtree, depth = 5 (3891 data points).
# Split on feature grade_E. (1721, 2170)
# --------------------------------------------------------------------
# Subtree, depth = 6 (1721 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (2170 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 5 (2083 data points).
# Split on feature grade_E. (2083, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (2083 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 4 (2253 data points).
# Split on feature grade_D. (2253, 0)
# --------------------------------------------------------------------
# Subtree, depth = 5 (2253 data points).
# Split on feature grade_E. (2253, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (2253 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 5 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 3 (1066 data points).
# Split on feature emp_length_5 years. (986, 80)
# --------------------------------------------------------------------
# Subtree, depth = 4 (986 data points).
# Split on feature emp_length_3 years. (900, 86)
# --------------------------------------------------------------------
# Subtree, depth = 5 (900 data points).
# Split on feature grade_C. (900, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (900 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 5 (86 data points).
# Split on feature home_ownership_MORTGAGE. (39, 47)
# --------------------------------------------------------------------
# Subtree, depth = 6 (39 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (47 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 4 (80 data points).
# Split on feature home_ownership_RENT. (58, 22)
# --------------------------------------------------------------------
# Subtree, depth = 5 (58 data points).
# Split on feature grade_C. (58, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (58 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 5 (22 data points).
# Split on feature grade_C. (22, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (22 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 2 (126 data points).
# Split on feature home_ownership_MORTGAGE. (36, 90)
# --------------------------------------------------------------------
# Subtree, depth = 3 (36 data points).
# Split on feature emp_length_< 1 year. (26, 10)
# --------------------------------------------------------------------
# Subtree, depth = 4 (26 data points).
# Split on feature emp_length_2 years. (23, 3)
# --------------------------------------------------------------------
# Subtree, depth = 5 (23 data points).
# Split on feature emp_length_5 years. (20, 3)
# --------------------------------------------------------------------
# Subtree, depth = 6 (20 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (3 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 5 (3 data points).
# Split on feature grade_B. (3, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (3 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 4 (10 data points).
# Split on feature grade_B. (10, 0)
# --------------------------------------------------------------------
# Subtree, depth = 5 (10 data points).
# Split on feature grade_C. (10, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (10 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 5 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 3 (90 data points).
# Split on feature grade_B. (90, 0)
# --------------------------------------------------------------------
# Subtree, depth = 4 (90 data points).
# Split on feature grade_C. (90, 0)
# --------------------------------------------------------------------
# Subtree, depth = 5 (90 data points).
# Split on feature grade_D. (90, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (90 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 5 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 4 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 1 (27621 data points).
# Split on feature grade_D. (22974, 4647)
# --------------------------------------------------------------------
# Subtree, depth = 2 (22974 data points).
# Split on feature grade_E. (21728, 1246)
# --------------------------------------------------------------------
# Subtree, depth = 3 (21728 data points).
# Split on feature grade_C. (14570, 7158)
# --------------------------------------------------------------------
# Subtree, depth = 4 (14570 data points).
# Split on feature grade_F. (14207, 363)
# --------------------------------------------------------------------
# Subtree, depth = 5 (14207 data points).
# Split on feature grade_G. (14097, 110)
# --------------------------------------------------------------------
# Subtree, depth = 6 (14097 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (110 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 5 (363 data points).
# Split on feature grade_A. (363, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (363 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 4 (7158 data points).
# Split on feature home_ownership_RENT. (3458, 3700)
# --------------------------------------------------------------------
# Subtree, depth = 5 (3458 data points).
# Split on feature emp_length_< 1 year. (3257, 201)
# --------------------------------------------------------------------
# Subtree, depth = 6 (3257 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (201 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 5 (3700 data points).
# Split on feature emp_length_2 years. (3279, 421)
# --------------------------------------------------------------------
# Subtree, depth = 6 (3279 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (421 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 3 (1246 data points).
# Split on feature grade_A. (1246, 0)
# --------------------------------------------------------------------
# Subtree, depth = 4 (1246 data points).
# Split on feature grade_B. (1246, 0)
# --------------------------------------------------------------------
# Subtree, depth = 5 (1246 data points).
# Split on feature grade_C. (1246, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (1246 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 5 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 4 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 2 (4647 data points).
# Split on feature grade_A. (4647, 0)
# --------------------------------------------------------------------
# Subtree, depth = 3 (4647 data points).
# Split on feature grade_B. (4647, 0)
# --------------------------------------------------------------------
# Subtree, depth = 4 (4647 data points).
# Split on feature grade_C. (4647, 0)
# --------------------------------------------------------------------
# Subtree, depth = 5 (4647 data points).
# Split on feature grade_E. (4647, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (4647 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 5 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 4 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 3 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 0 (37040 data points).
# Split on feature term_ 36 months. (9419, 27621)
# --------------------------------------------------------------------
# Subtree, depth = 1 (9419 data points).
# Split on feature grade_A. (9293, 126)
# --------------------------------------------------------------------
# Subtree, depth = 2 (9293 data points).
# Split on feature grade_B. (8227, 1066)
# --------------------------------------------------------------------
# Subtree, depth = 3 (8227 data points).
# Split on feature grade_C. (5974, 2253)
# --------------------------------------------------------------------
# Subtree, depth = 4 (5974 data points).
# Split on feature grade_D. (3891, 2083)
# --------------------------------------------------------------------
# Subtree, depth = 5 (3891 data points).
# Split on feature grade_E. (1721, 2170)
# --------------------------------------------------------------------
# Subtree, depth = 6 (1721 data points).
# Split on feature grade_F. (364, 1357)
# --------------------------------------------------------------------
# Subtree, depth = 7 (364 data points).
# Split on feature grade_G. (0, 364)
# --------------------------------------------------------------------
# Subtree, depth = 8 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 8 (364 data points).
# Split on feature term_ 60 months. (0, 364)
# --------------------------------------------------------------------
# Subtree, depth = 9 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 9 (364 data points).
# Split on feature home_ownership_MORTGAGE. (195, 169)
# --------------------------------------------------------------------
# Subtree, depth = 10 (195 data points).
# Split on feature home_ownership_OTHER. (195, 0)
# --------------------------------------------------------------------
# Subtree, depth = 11 (195 data points).
# Split on feature home_ownership_OWN. (157, 38)
# --------------------------------------------------------------------
# Subtree, depth = 12 (157 data points).
# Split on feature home_ownership_RENT. (0, 157)
# --------------------------------------------------------------------
# Subtree, depth = 13 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 13 (157 data points).
# Split on feature emp_length_1 year. (138, 19)
# --------------------------------------------------------------------
# Subtree, depth = 14 (138 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 14 (19 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 12 (38 data points).
# Split on feature emp_length_2 years. (34, 4)
# --------------------------------------------------------------------
# Subtree, depth = 13 (34 data points).
# Split on feature home_ownership_RENT. (34, 0)
# --------------------------------------------------------------------
# Subtree, depth = 14 (34 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 14 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 13 (4 data points).
# Split on feature home_ownership_RENT. (4, 0)
# --------------------------------------------------------------------
# Subtree, depth = 14 (4 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 14 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 11 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 10 (169 data points).
# Split on feature emp_length_2 years. (160, 9)
# --------------------------------------------------------------------
# Subtree, depth = 11 (160 data points).
# Split on feature home_ownership_OTHER. (160, 0)
# --------------------------------------------------------------------
# Subtree, depth = 12 (160 data points).
# Split on feature home_ownership_OWN. (160, 0)
# --------------------------------------------------------------------
# Subtree, depth = 13 (160 data points).
# Split on feature home_ownership_RENT. (160, 0)
# --------------------------------------------------------------------
# Subtree, depth = 14 (160 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 14 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 13 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 12 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 11 (9 data points).
# Split on feature home_ownership_OTHER. (9, 0)
# --------------------------------------------------------------------
# Subtree, depth = 12 (9 data points).
# Split on feature home_ownership_OWN. (9, 0)
# --------------------------------------------------------------------
# Subtree, depth = 13 (9 data points).
# Split on feature home_ownership_RENT. (9, 0)
# --------------------------------------------------------------------
# Subtree, depth = 14 (9 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 14 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 13 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 12 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 7 (1357 data points).
# Split on feature grade_G. (1357, 0)
# --------------------------------------------------------------------
# Subtree, depth = 8 (1357 data points).
# Split on feature term_ 60 months. (0, 1357)
# --------------------------------------------------------------------
# Subtree, depth = 9 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 9 (1357 data points).
# Split on feature home_ownership_MORTGAGE. (723, 634)
# --------------------------------------------------------------------
# Subtree, depth = 10 (723 data points).
# Split on feature home_ownership_OTHER. (723, 0)
# --------------------------------------------------------------------
# Subtree, depth = 11 (723 data points).
# Split on feature home_ownership_OWN. (615, 108)
# --------------------------------------------------------------------
# Subtree, depth = 12 (615 data points).
# Split on feature home_ownership_RENT. (0, 615)
# --------------------------------------------------------------------
# Subtree, depth = 13 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 13 (615 data points).
# Split on feature emp_length_1 year. (579, 36)
# --------------------------------------------------------------------
# Subtree, depth = 14 (579 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 14 (36 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 12 (108 data points).
# Split on feature home_ownership_RENT. (108, 0)
# --------------------------------------------------------------------
# Subtree, depth = 13 (108 data points).
# Split on feature emp_length_1 year. (103, 5)
# --------------------------------------------------------------------
# Subtree, depth = 14 (103 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 14 (5 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 13 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 11 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 10 (634 data points).
# Split on feature home_ownership_OTHER. (634, 0)
# --------------------------------------------------------------------
# Subtree, depth = 11 (634 data points).
# Split on feature home_ownership_OWN. (634, 0)
# --------------------------------------------------------------------
# Subtree, depth = 12 (634 data points).
# Split on feature home_ownership_RENT. (634, 0)
# --------------------------------------------------------------------
# Subtree, depth = 13 (634 data points).
# Split on feature emp_length_1 year. (599, 35)
# --------------------------------------------------------------------
# Subtree, depth = 14 (599 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 14 (35 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 13 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 12 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 11 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 8 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 6 (2170 data points).
# Split on feature grade_F. (2170, 0)
# --------------------------------------------------------------------
# Subtree, depth = 7 (2170 data points).
# Split on feature grade_G. (2170, 0)
# --------------------------------------------------------------------
# Subtree, depth = 8 (2170 data points).
# Split on feature term_ 60 months. (0, 2170)
# --------------------------------------------------------------------
# Subtree, depth = 9 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 9 (2170 data points).
# Split on feature home_ownership_MORTGAGE. (1032, 1138)
# --------------------------------------------------------------------
# Subtree, depth = 10 (1032 data points).
# Split on feature home_ownership_OTHER. (1031, 1)
# --------------------------------------------------------------------
# Subtree, depth = 11 (1031 data points).
# Split on feature home_ownership_OWN. (873, 158)
# --------------------------------------------------------------------
# Subtree, depth = 12 (873 data points).
# Split on feature home_ownership_RENT. (0, 873)
# --------------------------------------------------------------------
# Subtree, depth = 13 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 13 (873 data points).
# Split on feature emp_length_1 year. (807, 66)
# --------------------------------------------------------------------
# Subtree, depth = 14 (807 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 14 (66 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 12 (158 data points).
# Split on feature home_ownership_RENT. (158, 0)
# --------------------------------------------------------------------
# Subtree, depth = 13 (158 data points).
# Split on feature emp_length_1 year. (152, 6)
# --------------------------------------------------------------------
# Subtree, depth = 14 (152 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 14 (6 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 13 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 11 (1 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 10 (1138 data points).
# Split on feature home_ownership_OTHER. (1138, 0)
# --------------------------------------------------------------------
# Subtree, depth = 11 (1138 data points).
# Split on feature home_ownership_OWN. (1138, 0)
# --------------------------------------------------------------------
# Subtree, depth = 12 (1138 data points).
# Split on feature home_ownership_RENT. (1138, 0)
# --------------------------------------------------------------------
# Subtree, depth = 13 (1138 data points).
# Split on feature emp_length_1 year. (1081, 57)
# --------------------------------------------------------------------
# Subtree, depth = 14 (1081 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 14 (57 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 13 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 12 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 11 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 8 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 7 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 5 (2083 data points).
# Split on feature grade_E. (2083, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (2083 data points).
# Split on feature grade_F. (2083, 0)
# --------------------------------------------------------------------
# Subtree, depth = 7 (2083 data points).
# Split on feature grade_G. (2083, 0)
# --------------------------------------------------------------------
# Subtree, depth = 8 (2083 data points).
# Split on feature term_ 60 months. (0, 2083)
# --------------------------------------------------------------------
# Subtree, depth = 9 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 9 (2083 data points).
# Split on feature home_ownership_MORTGAGE. (941, 1142)
# --------------------------------------------------------------------
# Subtree, depth = 10 (941 data points).
# Split on feature home_ownership_OTHER. (940, 1)
# --------------------------------------------------------------------
# Subtree, depth = 11 (940 data points).
# Split on feature home_ownership_OWN. (767, 173)
# --------------------------------------------------------------------
# Subtree, depth = 12 (767 data points).
# Split on feature home_ownership_RENT. (0, 767)
# --------------------------------------------------------------------
# Subtree, depth = 13 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 13 (767 data points).
# Split on feature emp_length_1 year. (704, 63)
# --------------------------------------------------------------------
# Subtree, depth = 14 (704 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 14 (63 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 12 (173 data points).
# Split on feature emp_length_8 years. (168, 5)
# --------------------------------------------------------------------
# Subtree, depth = 13 (168 data points).
# Split on feature home_ownership_RENT. (168, 0)
# --------------------------------------------------------------------
# Subtree, depth = 14 (168 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 14 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 13 (5 data points).
# Split on feature home_ownership_RENT. (5, 0)
# --------------------------------------------------------------------
# Subtree, depth = 14 (5 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 14 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 11 (1 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 10 (1142 data points).
# Split on feature home_ownership_OTHER. (1142, 0)
# --------------------------------------------------------------------
# Subtree, depth = 11 (1142 data points).
# Split on feature home_ownership_OWN. (1142, 0)
# --------------------------------------------------------------------
# Subtree, depth = 12 (1142 data points).
# Split on feature home_ownership_RENT. (1142, 0)
# --------------------------------------------------------------------
# Subtree, depth = 13 (1142 data points).
# Split on feature emp_length_1 year. (1099, 43)
# --------------------------------------------------------------------
# Subtree, depth = 14 (1099 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 14 (43 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 13 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 12 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 11 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 8 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 7 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 4 (2253 data points).
# Split on feature grade_D. (2253, 0)
# --------------------------------------------------------------------
# Subtree, depth = 5 (2253 data points).
# Split on feature grade_E. (2253, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (2253 data points).
# Split on feature grade_F. (2253, 0)
# --------------------------------------------------------------------
# Subtree, depth = 7 (2253 data points).
# Split on feature grade_G. (2253, 0)
# --------------------------------------------------------------------
# Subtree, depth = 8 (2253 data points).
# Split on feature term_ 60 months. (0, 2253)
# --------------------------------------------------------------------
# Subtree, depth = 9 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 9 (2253 data points).
# Split on feature home_ownership_MORTGAGE. (847, 1406)
# --------------------------------------------------------------------
# Subtree, depth = 10 (847 data points).
# Split on feature emp_length_4 years. (780, 67)
# --------------------------------------------------------------------
# Subtree, depth = 11 (780 data points).
# Split on feature home_ownership_OTHER. (780, 0)
# --------------------------------------------------------------------
# Subtree, depth = 12 (780 data points).
# Split on feature home_ownership_OWN. (614, 166)
# --------------------------------------------------------------------
# Subtree, depth = 13 (614 data points).
# Split on feature home_ownership_RENT. (0, 614)
# --------------------------------------------------------------------
# Subtree, depth = 14 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 14 (614 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 13 (166 data points).
# Split on feature emp_length_10+ years. (100, 66)
# --------------------------------------------------------------------
# Subtree, depth = 14 (100 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 14 (66 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 12 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 11 (67 data points).
# Split on feature home_ownership_OTHER. (67, 0)
# --------------------------------------------------------------------
# Subtree, depth = 12 (67 data points).
# Split on feature home_ownership_OWN. (58, 9)
# --------------------------------------------------------------------
# Subtree, depth = 13 (58 data points).
# Split on feature home_ownership_RENT. (0, 58)
# --------------------------------------------------------------------
# Subtree, depth = 14 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 14 (58 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 13 (9 data points).
# Split on feature home_ownership_RENT. (9, 0)
# --------------------------------------------------------------------
# Subtree, depth = 14 (9 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 14 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 12 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 10 (1406 data points).
# Split on feature home_ownership_OTHER. (1406, 0)
# --------------------------------------------------------------------
# Subtree, depth = 11 (1406 data points).
# Split on feature home_ownership_OWN. (1406, 0)
# --------------------------------------------------------------------
# Subtree, depth = 12 (1406 data points).
# Split on feature home_ownership_RENT. (1406, 0)
# --------------------------------------------------------------------
# Subtree, depth = 13 (1406 data points).
# Split on feature emp_length_1 year. (1349, 57)
# --------------------------------------------------------------------
# Subtree, depth = 14 (1349 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 14 (57 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 13 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 12 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 11 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 8 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 7 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 5 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 3 (1066 data points).
# Split on feature emp_length_5 years. (986, 80)
# --------------------------------------------------------------------
# Subtree, depth = 4 (986 data points).
# Split on feature emp_length_3 years. (900, 86)
# --------------------------------------------------------------------
# Subtree, depth = 5 (900 data points).
# Split on feature grade_C. (900, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (900 data points).
# Split on feature grade_D. (900, 0)
# --------------------------------------------------------------------
# Subtree, depth = 7 (900 data points).
# Split on feature grade_E. (900, 0)
# --------------------------------------------------------------------
# Subtree, depth = 8 (900 data points).
# Split on feature grade_F. (900, 0)
# --------------------------------------------------------------------
# Subtree, depth = 9 (900 data points).
# Split on feature grade_G. (900, 0)
# --------------------------------------------------------------------
# Subtree, depth = 10 (900 data points).
# Split on feature term_ 60 months. (0, 900)
# --------------------------------------------------------------------
# Subtree, depth = 11 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 11 (900 data points).
# Split on feature home_ownership_MORTGAGE. (336, 564)
# --------------------------------------------------------------------
# Subtree, depth = 12 (336 data points).
# Split on feature emp_length_10+ years. (260, 76)
# --------------------------------------------------------------------
# Subtree, depth = 13 (260 data points).
# Split on feature home_ownership_OTHER. (260, 0)
# --------------------------------------------------------------------
# Subtree, depth = 14 (260 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 14 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 13 (76 data points).
# Split on feature home_ownership_OWN. (51, 25)
# --------------------------------------------------------------------
# Subtree, depth = 14 (51 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 14 (25 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 12 (564 data points).
# Split on feature emp_length_4 years. (525, 39)
# --------------------------------------------------------------------
# Subtree, depth = 13 (525 data points).
# Split on feature emp_length_9 years. (512, 13)
# --------------------------------------------------------------------
# Subtree, depth = 14 (512 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 14 (13 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 13 (39 data points).
# Split on feature home_ownership_OTHER. (39, 0)
# --------------------------------------------------------------------
# Subtree, depth = 14 (39 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 14 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 10 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 9 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 8 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 7 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 5 (86 data points).
# Split on feature home_ownership_MORTGAGE. (39, 47)
# --------------------------------------------------------------------
# Subtree, depth = 6 (39 data points).
# Split on feature grade_C. (39, 0)
# --------------------------------------------------------------------
# Subtree, depth = 7 (39 data points).
# Split on feature grade_D. (39, 0)
# --------------------------------------------------------------------
# Subtree, depth = 8 (39 data points).
# Split on feature grade_E. (39, 0)
# --------------------------------------------------------------------
# Subtree, depth = 9 (39 data points).
# Split on feature grade_F. (39, 0)
# --------------------------------------------------------------------
# Subtree, depth = 10 (39 data points).
# Split on feature grade_G. (39, 0)
# --------------------------------------------------------------------
# Subtree, depth = 11 (39 data points).
# Split on feature term_ 60 months. (0, 39)
# --------------------------------------------------------------------
# Subtree, depth = 12 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 12 (39 data points).
# Split on feature home_ownership_OTHER. (39, 0)
# --------------------------------------------------------------------
# Subtree, depth = 13 (39 data points).
# Split on feature home_ownership_OWN. (32, 7)
# --------------------------------------------------------------------
# Subtree, depth = 14 (32 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 14 (7 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 13 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 11 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 10 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 9 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 8 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 7 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 6 (47 data points).
# Split on feature grade_C. (47, 0)
# --------------------------------------------------------------------
# Subtree, depth = 7 (47 data points).
# Split on feature grade_D. (47, 0)
# --------------------------------------------------------------------
# Subtree, depth = 8 (47 data points).
# Split on feature grade_E. (47, 0)
# --------------------------------------------------------------------
# Subtree, depth = 9 (47 data points).
# Split on feature grade_F. (47, 0)
# --------------------------------------------------------------------
# Subtree, depth = 10 (47 data points).
# Split on feature grade_G. (47, 0)
# --------------------------------------------------------------------
# Subtree, depth = 11 (47 data points).
# Split on feature term_ 60 months. (0, 47)
# --------------------------------------------------------------------
# Subtree, depth = 12 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 12 (47 data points).
# Split on feature home_ownership_OTHER. (47, 0)
# --------------------------------------------------------------------
# Subtree, depth = 13 (47 data points).
# Split on feature home_ownership_OWN. (47, 0)
# --------------------------------------------------------------------
# Subtree, depth = 14 (47 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 14 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 13 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 11 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 10 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 9 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 8 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 7 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 4 (80 data points).
# Split on feature home_ownership_RENT. (58, 22)
# --------------------------------------------------------------------
# Subtree, depth = 5 (58 data points).
# Split on feature grade_C. (58, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (58 data points).
# Split on feature grade_D. (58, 0)
# --------------------------------------------------------------------
# Subtree, depth = 7 (58 data points).
# ...
# --------------------------------------------------------------------
# Subtree, depth = 11 (421 data points).
# Split on feature home_ownership_MORTGAGE. (421, 0)
# --------------------------------------------------------------------
# Subtree, depth = 12 (421 data points).
# Split on feature home_ownership_OTHER. (421, 0)
# --------------------------------------------------------------------
# Subtree, depth = 13 (421 data points).
# Split on feature home_ownership_OWN. (421, 0)
# --------------------------------------------------------------------
# Subtree, depth = 14 (421 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 14 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 13 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 12 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 11 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 10 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 9 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 8 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 7 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 3 (1246 data points).
# Split on feature grade_A. (1246, 0)
# --------------------------------------------------------------------
# Subtree, depth = 4 (1246 data points).
# Split on feature grade_B. (1246, 0)
# --------------------------------------------------------------------
# Subtree, depth = 5 (1246 data points).
# Split on feature grade_C. (1246, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (1246 data points).
# Split on feature grade_F. (1246, 0)
# --------------------------------------------------------------------
# Subtree, depth = 7 (1246 data points).
# Split on feature grade_G. (1246, 0)
# --------------------------------------------------------------------
# Subtree, depth = 8 (1246 data points).
# Split on feature term_ 60 months. (1246, 0)
# --------------------------------------------------------------------
# Subtree, depth = 9 (1246 data points).
# Split on feature home_ownership_MORTGAGE. (834, 412)
# --------------------------------------------------------------------
# Subtree, depth = 10 (834 data points).
# Split on feature home_ownership_OTHER. (831, 3)
# --------------------------------------------------------------------
# Subtree, depth = 11 (831 data points).
# Split on feature home_ownership_OWN. (733, 98)
# --------------------------------------------------------------------
# Subtree, depth = 12 (733 data points).
# Split on feature home_ownership_RENT. (0, 733)
# --------------------------------------------------------------------
# Subtree, depth = 13 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 13 (733 data points).
# Split on feature emp_length_1 year. (661, 72)
# --------------------------------------------------------------------
# Subtree, depth = 14 (661 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 14 (72 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 12 (98 data points).
# Split on feature emp_length_3 years. (94, 4)
# --------------------------------------------------------------------
# Subtree, depth = 13 (94 data points).
# Split on feature home_ownership_RENT. (94, 0)
# --------------------------------------------------------------------
# Subtree, depth = 14 (94 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 14 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 13 (4 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 11 (3 data points).
# Split on feature home_ownership_OWN. (3, 0)
# --------------------------------------------------------------------
# Subtree, depth = 12 (3 data points).
# Split on feature home_ownership_RENT. (3, 0)
# --------------------------------------------------------------------
# Subtree, depth = 13 (3 data points).
# Split on feature emp_length_1 year. (3, 0)
# --------------------------------------------------------------------
# Subtree, depth = 14 (3 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 14 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 13 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 12 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 10 (412 data points).
# Split on feature emp_length_3 years. (377, 35)
# --------------------------------------------------------------------
# Subtree, depth = 11 (377 data points).
# Split on feature home_ownership_OTHER. (377, 0)
# --------------------------------------------------------------------
# Subtree, depth = 12 (377 data points).
# Split on feature home_ownership_OWN. (377, 0)
# --------------------------------------------------------------------
# Subtree, depth = 13 (377 data points).
# Split on feature home_ownership_RENT. (377, 0)
# --------------------------------------------------------------------
# Subtree, depth = 14 (377 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 14 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 13 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 12 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 11 (35 data points).
# Split on feature home_ownership_OTHER. (35, 0)
# --------------------------------------------------------------------
# Subtree, depth = 12 (35 data points).
# Split on feature home_ownership_OWN. (35, 0)
# --------------------------------------------------------------------
# Subtree, depth = 13 (35 data points).
# Split on feature home_ownership_RENT. (35, 0)
# --------------------------------------------------------------------
# Subtree, depth = 14 (35 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 14 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 13 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 12 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 9 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 8 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 7 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 5 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 4 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 2 (4647 data points).
# Split on feature grade_A. (4647, 0)
# --------------------------------------------------------------------
# Subtree, depth = 3 (4647 data points).
# Split on feature grade_B. (4647, 0)
# --------------------------------------------------------------------
# Subtree, depth = 4 (4647 data points).
# Split on feature grade_C. (4647, 0)
# --------------------------------------------------------------------
# Subtree, depth = 5 (4647 data points).
# Split on feature grade_E. (4647, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (4647 data points).
# Split on feature grade_F. (4647, 0)
# --------------------------------------------------------------------
# Subtree, depth = 7 (4647 data points).
# Split on feature grade_G. (4647, 0)
# --------------------------------------------------------------------
# Subtree, depth = 8 (4647 data points).
# Split on feature term_ 60 months. (4647, 0)
# --------------------------------------------------------------------
# Subtree, depth = 9 (4647 data points).
# Split on feature home_ownership_MORTGAGE. (3057, 1590)
# --------------------------------------------------------------------
# Subtree, depth = 10 (3057 data points).
# Split on feature home_ownership_OTHER. (3047, 10)
# --------------------------------------------------------------------
# Subtree, depth = 11 (3047 data points).
# Split on feature home_ownership_OWN. (2598, 449)
# --------------------------------------------------------------------
# Subtree, depth = 12 (2598 data points).
# Split on feature home_ownership_RENT. (0, 2598)
# --------------------------------------------------------------------
# Subtree, depth = 13 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 13 (2598 data points).
# Split on feature emp_length_1 year. (2353, 245)
# --------------------------------------------------------------------
# Subtree, depth = 14 (2353 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 14 (245 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 12 (449 data points).
# Split on feature emp_length_1 year. (409, 40)
# --------------------------------------------------------------------
# Subtree, depth = 13 (409 data points).
# Split on feature emp_length_< 1 year. (367, 42)
# --------------------------------------------------------------------
# Subtree, depth = 14 (367 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 14 (42 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 13 (40 data points).
# Split on feature home_ownership_RENT. (40, 0)
# --------------------------------------------------------------------
# Subtree, depth = 14 (40 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 14 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 11 (10 data points).
# Split on feature emp_length_8 years. (9, 1)
# --------------------------------------------------------------------
# Subtree, depth = 12 (9 data points).
# Split on feature home_ownership_OWN. (9, 0)
# --------------------------------------------------------------------
# Subtree, depth = 13 (9 data points).
# Split on feature home_ownership_RENT. (9, 0)
# --------------------------------------------------------------------
# Subtree, depth = 14 (9 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 14 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 13 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 12 (1 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 10 (1590 data points).
# Split on feature emp_length_9 years. (1533, 57)
# --------------------------------------------------------------------
# Subtree, depth = 11 (1533 data points).
# Split on feature home_ownership_OTHER. (1533, 0)
# --------------------------------------------------------------------
# Subtree, depth = 12 (1533 data points).
# Split on feature home_ownership_OWN. (1533, 0)
# --------------------------------------------------------------------
# Subtree, depth = 13 (1533 data points).
# Split on feature home_ownership_RENT. (1533, 0)
# --------------------------------------------------------------------
# Subtree, depth = 14 (1533 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 14 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 13 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 12 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 11 (57 data points).
# Split on feature home_ownership_OTHER. (57, 0)
# --------------------------------------------------------------------
# Subtree, depth = 12 (57 data points).
# Split on feature home_ownership_OWN. (57, 0)
# --------------------------------------------------------------------
# Subtree, depth = 13 (57 data points).
# Split on feature home_ownership_RENT. (57, 0)
# --------------------------------------------------------------------
# Subtree, depth = 14 (57 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 14 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 13 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 12 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 9 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 8 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 7 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 5 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 4 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 3 (0 data points).
# Stopping condition 1 reached.

# %% [markdown]
# ### Evaluating the models
#
# Let us evaluate the models on the **train** and **validation** set. Let us start by evaluating the classification error on the training data:

# %%
print("Training data, classification error (model 1):", evaluate_classification_error(model_1, train_data, target))
print("Training data, classification error (model 2):", evaluate_classification_error(model_2, train_data, target))
print("Training data, classification error (model 3):", evaluate_classification_error(model_3, train_data, target))
# Out:
# Training data, classification error (model 1): 0.4019708423326134
# Training data, classification error (model 2): 0.3822084233261339
# Training data, classification error (model 3): 0.3801295896328294

# %% [markdown]
# Now evaluate the classification error on the validation set.

# %%
# YOUR CODE HERE
print("Validation data, classification error (model 1):", evaluate_classification_error(model_1, validation_data, target))
print("Validation data, classification error (model 2):", evaluate_classification_error(model_2, validation_data, target))
print("Validation data, classification error (model 3):", evaluate_classification_error(model_3, validation_data, target))
# Out:
# Validation data, classification error (model 1): 0.4037796976241901
# Validation data, classification error (model 2): 0.3827213822894169
# Validation data, classification error (model 3): 0.38747300215982716

# %% [markdown]
# **Quiz Question:** Which tree has the smallest error on the validation set?
# <br>
# **Your answer:**
# <br>
# **Quiz Question:** Does the tree with the smallest error in the training data also have the smallest error in the validation set?
# <br>
# **Your answer:**
# <br>
# **Quiz Question:** Is it always true that the tree with the lowest classification error on the **training** set will result in the lowest classification error in the **validation** set?
# <br>
# **Your answer:**
#
# ### Measuring the complexity of the tree
#
# Recall in the lecture that we talked about deeper trees being more complex. We will measure the complexity of the tree as
#
# ```
#   complexity(T) = number of leaves in the tree T
# ```
#
# Here, we provide a function `count_leaves` that counts the number of leaves in a tree. Using this implementation, compute the number of nodes in `model_1`, `model_2`, and `model_3`.

# %%
def count_leaves(tree):
    if tree['is_leaf']:
        return 1
    return count_leaves(tree['left']) + count_leaves(tree['right'])

# %%
# YOUR CODE HERE
print(count_leaves(model_1))
print(count_leaves(model_2))
print(count_leaves(model_3))
# Out:
# 4
# 43
# 379

# %% [markdown]
# **Quiz Question:** Which tree has the largest complexity?
# <br>
# **Your answer:**
# <br>
# **Quiz Question:** Is it always true that the most complex tree will result in the lowest classification error in the **validation_set**?
# <br>
# **Your answer:**

# %% [markdown]
# # Exploring the effect of min_error
#
# We will compare three models trained with different values of the stopping criterion. We intentionally picked models at the extreme ends (**negative**, **just right**, and **too positive**).
#
# Train three models with these parameters:
# 1. **model_4**: `min_error_reduction = -1` (ignoring this early stopping condition)
# 2. **model_5**: `min_error_reduction = 0` (just right)
# 3. **model_6**: `min_error_reduction = 5` (too positive)
#
# For each of these three, we set `max_depth = 6`, and `min_node_size = 0`.
#
# ** Note:** Each tree can take up to 30 seconds to train.

# %%
# YOUR CODE HERE
model_4 = decision_tree_create(train_data, features, 'safe_loans', max_depth = 6, 
                                min_node_size = 0, min_error_reduction=-1)
model_5 = decision_tree_create(train_data, features, 'safe_loans', max_depth = 6, 
                                min_node_size = 0, min_error_reduction=0)
model_6 = decision_tree_create(train_data, features, 'safe_loans', max_depth = 6, 
                                min_node_size = 0, min_error_reduction=5)
# Out:
# --------------------------------------------------------------------
# Subtree, depth = 0 (37040 data points).
# Split on feature term_ 36 months. (9419, 27621)
# --------------------------------------------------------------------
# Subtree, depth = 1 (9419 data points).
# Split on feature grade_A. (9293, 126)
# --------------------------------------------------------------------
# Subtree, depth = 2 (9293 data points).
# Split on feature grade_B. (8227, 1066)
# --------------------------------------------------------------------
# Subtree, depth = 3 (8227 data points).
# Split on feature grade_C. (5974, 2253)
# --------------------------------------------------------------------
# Subtree, depth = 4 (5974 data points).
# Split on feature grade_D. (3891, 2083)
# --------------------------------------------------------------------
# Subtree, depth = 5 (3891 data points).
# Split on feature grade_E. (1721, 2170)
# --------------------------------------------------------------------
# Subtree, depth = 6 (1721 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (2170 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 5 (2083 data points).
# Split on feature grade_E. (2083, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (2083 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 4 (2253 data points).
# Split on feature grade_D. (2253, 0)
# --------------------------------------------------------------------
# Subtree, depth = 5 (2253 data points).
# Split on feature grade_E. (2253, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (2253 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 5 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 3 (1066 data points).
# Split on feature emp_length_5 years. (986, 80)
# --------------------------------------------------------------------
# Subtree, depth = 4 (986 data points).
# Split on feature emp_length_3 years. (900, 86)
# --------------------------------------------------------------------
# Subtree, depth = 5 (900 data points).
# Split on feature grade_C. (900, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (900 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 5 (86 data points).
# Split on feature home_ownership_MORTGAGE. (39, 47)
# --------------------------------------------------------------------
# Subtree, depth = 6 (39 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (47 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 4 (80 data points).
# Split on feature home_ownership_RENT. (58, 22)
# --------------------------------------------------------------------
# Subtree, depth = 5 (58 data points).
# Split on feature grade_C. (58, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (58 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 5 (22 data points).
# Split on feature grade_C. (22, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (22 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 2 (126 data points).
# Split on feature home_ownership_MORTGAGE. (36, 90)
# --------------------------------------------------------------------
# Subtree, depth = 3 (36 data points).
# Split on feature emp_length_< 1 year. (26, 10)
# --------------------------------------------------------------------
# Subtree, depth = 4 (26 data points).
# Split on feature emp_length_2 years. (23, 3)
# --------------------------------------------------------------------
# Subtree, depth = 5 (23 data points).
# Split on feature emp_length_5 years. (20, 3)
# --------------------------------------------------------------------
# Subtree, depth = 6 (20 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (3 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 5 (3 data points).
# Split on feature grade_B. (3, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (3 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 4 (10 data points).
# Split on feature grade_B. (10, 0)
# --------------------------------------------------------------------
# Subtree, depth = 5 (10 data points).
# Split on feature grade_C. (10, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (10 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 5 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 3 (90 data points).
# Split on feature grade_B. (90, 0)
# --------------------------------------------------------------------
# Subtree, depth = 4 (90 data points).
# Split on feature grade_C. (90, 0)
# --------------------------------------------------------------------
# Subtree, depth = 5 (90 data points).
# Split on feature grade_D. (90, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (90 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 5 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 4 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 1 (27621 data points).
# Split on feature grade_D. (22974, 4647)
# --------------------------------------------------------------------
# Subtree, depth = 2 (22974 data points).
# Split on feature grade_E. (21728, 1246)
# --------------------------------------------------------------------
# Subtree, depth = 3 (21728 data points).
# Split on feature grade_C. (14570, 7158)
# --------------------------------------------------------------------
# Subtree, depth = 4 (14570 data points).
# Split on feature grade_F. (14207, 363)
# --------------------------------------------------------------------
# Subtree, depth = 5 (14207 data points).
# Split on feature grade_G. (14097, 110)
# --------------------------------------------------------------------
# Subtree, depth = 6 (14097 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (110 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 5 (363 data points).
# Split on feature grade_A. (363, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (363 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 4 (7158 data points).
# Split on feature home_ownership_RENT. (3458, 3700)
# --------------------------------------------------------------------
# Subtree, depth = 5 (3458 data points).
# Split on feature emp_length_< 1 year. (3257, 201)
# --------------------------------------------------------------------
# Subtree, depth = 6 (3257 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (201 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 5 (3700 data points).
# Split on feature emp_length_2 years. (3279, 421)
# --------------------------------------------------------------------
# Subtree, depth = 6 (3279 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (421 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 3 (1246 data points).
# Split on feature grade_A. (1246, 0)
# --------------------------------------------------------------------
# Subtree, depth = 4 (1246 data points).
# Split on feature grade_B. (1246, 0)
# --------------------------------------------------------------------
# Subtree, depth = 5 (1246 data points).
# Split on feature grade_C. (1246, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (1246 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 5 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 4 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 2 (4647 data points).
# Split on feature grade_A. (4647, 0)
# --------------------------------------------------------------------
# Subtree, depth = 3 (4647 data points).
# Split on feature grade_B. (4647, 0)
# --------------------------------------------------------------------
# Subtree, depth = 4 (4647 data points).
# Split on feature grade_C. (4647, 0)
# --------------------------------------------------------------------
# Subtree, depth = 5 (4647 data points).
# Split on feature grade_E. (4647, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (4647 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 5 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 4 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 3 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 0 (37040 data points).
# Split on feature term_ 36 months. (9419, 27621)
# --------------------------------------------------------------------
# Subtree, depth = 1 (9419 data points).
# Split on feature grade_A. (9293, 126)
# --------------------------------------------------------------------
# Subtree, depth = 2 (9293 data points).
# Split on feature grade_B. (8227, 1066)
# --------------------------------------------------------------------
# Subtree, depth = 3 (8227 data points).
# Split on feature grade_C. (5974, 2253)
# --------------------------------------------------------------------
# Subtree, depth = 4 (5974 data points).
# Split on feature grade_D. (3891, 2083)
# --------------------------------------------------------------------
# Subtree, depth = 5 (3891 data points).
# Split on feature grade_E. (1721, 2170)
# --------------------------------------------------------------------
# Subtree, depth = 6 (1721 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (2170 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 5 (2083 data points).
# Split on feature grade_E. (2083, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (2083 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 4 (2253 data points).
# Split on feature grade_D. (2253, 0)
# --------------------------------------------------------------------
# Subtree, depth = 5 (2253 data points).
# Split on feature grade_E. (2253, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (2253 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 5 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 3 (1066 data points).
# Split on feature emp_length_5 years. (986, 80)
# --------------------------------------------------------------------
# Subtree, depth = 4 (986 data points).
# Split on feature emp_length_3 years. (900, 86)
# --------------------------------------------------------------------
# Subtree, depth = 5 (900 data points).
# Split on feature grade_C. (900, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (900 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 5 (86 data points).
# Split on feature home_ownership_MORTGAGE. (39, 47)
# --------------------------------------------------------------------
# Subtree, depth = 6 (39 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (47 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 4 (80 data points).
# Split on feature home_ownership_RENT. (58, 22)
# --------------------------------------------------------------------
# Subtree, depth = 5 (58 data points).
# Split on feature grade_C. (58, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (58 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 5 (22 data points).
# Split on feature grade_C. (22, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (22 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 2 (126 data points).
# Split on feature home_ownership_MORTGAGE. (36, 90)
# --------------------------------------------------------------------
# Subtree, depth = 3 (36 data points).
# Split on feature emp_length_< 1 year. (26, 10)
# --------------------------------------------------------------------
# Subtree, depth = 4 (26 data points).
# Split on feature emp_length_2 years. (23, 3)
# --------------------------------------------------------------------
# Subtree, depth = 5 (23 data points).
# Split on feature emp_length_5 years. (20, 3)
# --------------------------------------------------------------------
# Subtree, depth = 6 (20 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (3 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 5 (3 data points).
# Split on feature grade_B. (3, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (3 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 4 (10 data points).
# Split on feature grade_B. (10, 0)
# --------------------------------------------------------------------
# Subtree, depth = 5 (10 data points).
# Split on feature grade_C. (10, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (10 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 5 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 3 (90 data points).
# Split on feature grade_B. (90, 0)
# --------------------------------------------------------------------
# Subtree, depth = 4 (90 data points).
# Split on feature grade_C. (90, 0)
# --------------------------------------------------------------------
# Subtree, depth = 5 (90 data points).
# Split on feature grade_D. (90, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (90 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 5 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 4 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 1 (27621 data points).
# Split on feature grade_D. (22974, 4647)
# --------------------------------------------------------------------
# Subtree, depth = 2 (22974 data points).
# Split on feature grade_E. (21728, 1246)
# --------------------------------------------------------------------
# Subtree, depth = 3 (21728 data points).
# Split on feature grade_C. (14570, 7158)
# --------------------------------------------------------------------
# Subtree, depth = 4 (14570 data points).
# Split on feature grade_F. (14207, 363)
# --------------------------------------------------------------------
# Subtree, depth = 5 (14207 data points).
# Split on feature grade_G. (14097, 110)
# --------------------------------------------------------------------
# Subtree, depth = 6 (14097 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (110 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 5 (363 data points).
# Split on feature grade_A. (363, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (363 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 4 (7158 data points).
# Split on feature home_ownership_RENT. (3458, 3700)
# --------------------------------------------------------------------
# Subtree, depth = 5 (3458 data points).
# Split on feature emp_length_< 1 year. (3257, 201)
# --------------------------------------------------------------------
# Subtree, depth = 6 (3257 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (201 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 5 (3700 data points).
# Split on feature emp_length_2 years. (3279, 421)
# --------------------------------------------------------------------
# Subtree, depth = 6 (3279 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (421 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 3 (1246 data points).
# Split on feature grade_A. (1246, 0)
# --------------------------------------------------------------------
# Subtree, depth = 4 (1246 data points).
# Split on feature grade_B. (1246, 0)
# --------------------------------------------------------------------
# Subtree, depth = 5 (1246 data points).
# Split on feature grade_C. (1246, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (1246 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 5 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 4 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 2 (4647 data points).
# Split on feature grade_A. (4647, 0)
# --------------------------------------------------------------------
# Subtree, depth = 3 (4647 data points).
# Split on feature grade_B. (4647, 0)
# --------------------------------------------------------------------
# Subtree, depth = 4 (4647 data points).
# Split on feature grade_C. (4647, 0)
# --------------------------------------------------------------------
# Subtree, depth = 5 (4647 data points).
# Split on feature grade_E. (4647, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (4647 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 5 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 4 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 3 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 0 (37040 data points).
# Early stopping condition 3 reached. Minimum error reduction.

# %% [markdown]
# Calculate the accuracy of each model (**model_4**, **model_5**, or **model_6**) on the validation set.

# %%
# YOUR CODE HERE
print ("Validation data, classification error (model 4):", evaluate_classification_error(model_4, validation_data, target))
print ("Validation data, classification error (model 5):", evaluate_classification_error(model_5, validation_data, target))
print ("Validation data, classification error (model 6):", evaluate_classification_error(model_6, validation_data, target))
# Out:
# Validation data, classification error (model 4): 0.3827213822894169
# Validation data, classification error (model 5): 0.3827213822894169
# Validation data, classification error (model 6): 0.5029157667386609

# %% [markdown]
# Using the `count_leaves` function, compute the number of leaves in each of each models in (**model_4**, **model_5**, and **model_6**).

# %%
print("Complexity (model 4):", count_leaves(model_4))
print("Complexity (model 5):", count_leaves(model_5))
print("Complexity (model 6):", count_leaves(model_6))
# Out:
# Complexity (model 4): 43
# Complexity (model 5): 43
# Complexity (model 6): 1

# %% [markdown]
# **Quiz Question:** Using the complexity definition above, which model (**model_4**, **model_5**, or **model_6**) has the largest complexity?
# <br>
# **Your answer:**
# <br>
# Did this match your expectation?

# %% [markdown]
# # Exploring the effect of min_node_size
#
# We will compare three models trained with different values of the stopping criterion. Again, intentionally picked models at the extreme ends (**too small**, **just right**, and **just right**).
#
# Train three models with these parameters:
# 1. **model_7**: min_node_size = 0 (too small)
# 2. **model_8**: min_node_size = 2000 (just right)
# 3. **model_9**: min_node_size = 50000 (too large)
#
# For each of these three, we set `max_depth = 6`, and `min_error_reduction = -1`.
#
# ** Note:** Each tree can take up to 30 seconds to train.

# %%
model_7 = decision_tree_create(train_data, features, 'safe_loans', max_depth = 6, 
                                min_node_size = 0, min_error_reduction=-1)
model_8 = decision_tree_create(train_data, features, 'safe_loans', max_depth = 6, 
                                min_node_size = 2000, min_error_reduction=-1)
model_9 = decision_tree_create(train_data, features, 'safe_loans', max_depth = 6, 
                                min_node_size = 50000, min_error_reduction=-1)
# Out:
# --------------------------------------------------------------------
# Subtree, depth = 0 (37040 data points).
# Split on feature term_ 36 months. (9419, 27621)
# --------------------------------------------------------------------
# Subtree, depth = 1 (9419 data points).
# Split on feature grade_A. (9293, 126)
# --------------------------------------------------------------------
# Subtree, depth = 2 (9293 data points).
# Split on feature grade_B. (8227, 1066)
# --------------------------------------------------------------------
# Subtree, depth = 3 (8227 data points).
# Split on feature grade_C. (5974, 2253)
# --------------------------------------------------------------------
# Subtree, depth = 4 (5974 data points).
# Split on feature grade_D. (3891, 2083)
# --------------------------------------------------------------------
# Subtree, depth = 5 (3891 data points).
# Split on feature grade_E. (1721, 2170)
# --------------------------------------------------------------------
# Subtree, depth = 6 (1721 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (2170 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 5 (2083 data points).
# Split on feature grade_E. (2083, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (2083 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 4 (2253 data points).
# Split on feature grade_D. (2253, 0)
# --------------------------------------------------------------------
# Subtree, depth = 5 (2253 data points).
# Split on feature grade_E. (2253, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (2253 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 5 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 3 (1066 data points).
# Split on feature emp_length_5 years. (986, 80)
# --------------------------------------------------------------------
# Subtree, depth = 4 (986 data points).
# Split on feature emp_length_3 years. (900, 86)
# --------------------------------------------------------------------
# Subtree, depth = 5 (900 data points).
# Split on feature grade_C. (900, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (900 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 5 (86 data points).
# Split on feature home_ownership_MORTGAGE. (39, 47)
# --------------------------------------------------------------------
# Subtree, depth = 6 (39 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (47 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 4 (80 data points).
# Split on feature home_ownership_RENT. (58, 22)
# --------------------------------------------------------------------
# Subtree, depth = 5 (58 data points).
# Split on feature grade_C. (58, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (58 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 5 (22 data points).
# Split on feature grade_C. (22, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (22 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 2 (126 data points).
# Split on feature home_ownership_MORTGAGE. (36, 90)
# --------------------------------------------------------------------
# Subtree, depth = 3 (36 data points).
# Split on feature emp_length_< 1 year. (26, 10)
# --------------------------------------------------------------------
# Subtree, depth = 4 (26 data points).
# Split on feature emp_length_2 years. (23, 3)
# --------------------------------------------------------------------
# Subtree, depth = 5 (23 data points).
# Split on feature emp_length_5 years. (20, 3)
# --------------------------------------------------------------------
# Subtree, depth = 6 (20 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (3 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 5 (3 data points).
# Split on feature grade_B. (3, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (3 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 4 (10 data points).
# Split on feature grade_B. (10, 0)
# --------------------------------------------------------------------
# Subtree, depth = 5 (10 data points).
# Split on feature grade_C. (10, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (10 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 5 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 3 (90 data points).
# Split on feature grade_B. (90, 0)
# --------------------------------------------------------------------
# Subtree, depth = 4 (90 data points).
# Split on feature grade_C. (90, 0)
# --------------------------------------------------------------------
# Subtree, depth = 5 (90 data points).
# Split on feature grade_D. (90, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (90 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 5 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 4 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 1 (27621 data points).
# Split on feature grade_D. (22974, 4647)
# --------------------------------------------------------------------
# Subtree, depth = 2 (22974 data points).
# Split on feature grade_E. (21728, 1246)
# --------------------------------------------------------------------
# Subtree, depth = 3 (21728 data points).
# Split on feature grade_C. (14570, 7158)
# --------------------------------------------------------------------
# Subtree, depth = 4 (14570 data points).
# Split on feature grade_F. (14207, 363)
# --------------------------------------------------------------------
# Subtree, depth = 5 (14207 data points).
# Split on feature grade_G. (14097, 110)
# --------------------------------------------------------------------
# Subtree, depth = 6 (14097 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (110 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 5 (363 data points).
# Split on feature grade_A. (363, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (363 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 4 (7158 data points).
# Split on feature home_ownership_RENT. (3458, 3700)
# --------------------------------------------------------------------
# Subtree, depth = 5 (3458 data points).
# Split on feature emp_length_< 1 year. (3257, 201)
# --------------------------------------------------------------------
# Subtree, depth = 6 (3257 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (201 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 5 (3700 data points).
# Split on feature emp_length_2 years. (3279, 421)
# --------------------------------------------------------------------
# Subtree, depth = 6 (3279 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (421 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 3 (1246 data points).
# Split on feature grade_A. (1246, 0)
# --------------------------------------------------------------------
# Subtree, depth = 4 (1246 data points).
# Split on feature grade_B. (1246, 0)
# --------------------------------------------------------------------
# Subtree, depth = 5 (1246 data points).
# Split on feature grade_C. (1246, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (1246 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 5 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 4 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 2 (4647 data points).
# Split on feature grade_A. (4647, 0)
# --------------------------------------------------------------------
# Subtree, depth = 3 (4647 data points).
# Split on feature grade_B. (4647, 0)
# --------------------------------------------------------------------
# Subtree, depth = 4 (4647 data points).
# Split on feature grade_C. (4647, 0)
# --------------------------------------------------------------------
# Subtree, depth = 5 (4647 data points).
# Split on feature grade_E. (4647, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (4647 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 5 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 4 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 3 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 0 (37040 data points).
# Split on feature term_ 36 months. (9419, 27621)
# --------------------------------------------------------------------
# Subtree, depth = 1 (9419 data points).
# Split on feature grade_A. (9293, 126)
# --------------------------------------------------------------------
# Subtree, depth = 2 (9293 data points).
# Split on feature grade_B. (8227, 1066)
# --------------------------------------------------------------------
# Subtree, depth = 3 (8227 data points).
# Split on feature grade_C. (5974, 2253)
# --------------------------------------------------------------------
# Subtree, depth = 4 (5974 data points).
# Split on feature grade_D. (3891, 2083)
# --------------------------------------------------------------------
# Subtree, depth = 5 (3891 data points).
# Split on feature grade_E. (1721, 2170)
# --------------------------------------------------------------------
# Subtree, depth = 6 (1721 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (2170 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 5 (2083 data points).
# Split on feature grade_E. (2083, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (2083 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 4 (2253 data points).
# Split on feature grade_D. (2253, 0)
# --------------------------------------------------------------------
# Subtree, depth = 5 (2253 data points).
# Split on feature grade_E. (2253, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (2253 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 5 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 3 (1066 data points).
# Split on feature emp_length_5 years. (986, 80)
# --------------------------------------------------------------------
# Subtree, depth = 4 (986 data points).
# Split on feature emp_length_3 years. (900, 86)
# --------------------------------------------------------------------
# Subtree, depth = 5 (900 data points).
# Split on feature grade_C. (900, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (900 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 5 (86 data points).
# Split on feature home_ownership_MORTGAGE. (39, 47)
# --------------------------------------------------------------------
# Subtree, depth = 6 (39 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (47 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 4 (80 data points).
# Split on feature home_ownership_RENT. (58, 22)
# --------------------------------------------------------------------
# Subtree, depth = 5 (58 data points).
# Split on feature grade_C. (58, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (58 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 5 (22 data points).
# Split on feature grade_C. (22, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (22 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 2 (126 data points).
# Split on feature home_ownership_MORTGAGE. (36, 90)
# --------------------------------------------------------------------
# Subtree, depth = 3 (36 data points).
# Split on feature emp_length_< 1 year. (26, 10)
# --------------------------------------------------------------------
# Subtree, depth = 4 (26 data points).
# Split on feature emp_length_2 years. (23, 3)
# --------------------------------------------------------------------
# Subtree, depth = 5 (23 data points).
# Split on feature emp_length_5 years. (20, 3)
# --------------------------------------------------------------------
# Subtree, depth = 6 (20 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (3 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 5 (3 data points).
# Split on feature grade_B. (3, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (3 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 4 (10 data points).
# Split on feature grade_B. (10, 0)
# --------------------------------------------------------------------
# Subtree, depth = 5 (10 data points).
# Split on feature grade_C. (10, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (10 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 5 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 3 (90 data points).
# Split on feature grade_B. (90, 0)
# --------------------------------------------------------------------
# Subtree, depth = 4 (90 data points).
# Split on feature grade_C. (90, 0)
# --------------------------------------------------------------------
# Subtree, depth = 5 (90 data points).
# Split on feature grade_D. (90, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (90 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 5 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 4 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 1 (27621 data points).
# Split on feature grade_D. (22974, 4647)
# --------------------------------------------------------------------
# Subtree, depth = 2 (22974 data points).
# Split on feature grade_E. (21728, 1246)
# --------------------------------------------------------------------
# Subtree, depth = 3 (21728 data points).
# Split on feature grade_C. (14570, 7158)
# --------------------------------------------------------------------
# Subtree, depth = 4 (14570 data points).
# Split on feature grade_F. (14207, 363)
# --------------------------------------------------------------------
# Subtree, depth = 5 (14207 data points).
# Split on feature grade_G. (14097, 110)
# --------------------------------------------------------------------
# Subtree, depth = 6 (14097 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (110 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 5 (363 data points).
# Split on feature grade_A. (363, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (363 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 4 (7158 data points).
# Split on feature home_ownership_RENT. (3458, 3700)
# --------------------------------------------------------------------
# Subtree, depth = 5 (3458 data points).
# Split on feature emp_length_< 1 year. (3257, 201)
# --------------------------------------------------------------------
# Subtree, depth = 6 (3257 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (201 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 5 (3700 data points).
# Split on feature emp_length_2 years. (3279, 421)
# --------------------------------------------------------------------
# Subtree, depth = 6 (3279 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (421 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 3 (1246 data points).
# Split on feature grade_A. (1246, 0)
# --------------------------------------------------------------------
# Subtree, depth = 4 (1246 data points).
# Split on feature grade_B. (1246, 0)
# --------------------------------------------------------------------
# Subtree, depth = 5 (1246 data points).
# Split on feature grade_C. (1246, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (1246 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 5 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 4 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 2 (4647 data points).
# Split on feature grade_A. (4647, 0)
# --------------------------------------------------------------------
# Subtree, depth = 3 (4647 data points).
# Split on feature grade_B. (4647, 0)
# --------------------------------------------------------------------
# Subtree, depth = 4 (4647 data points).
# Split on feature grade_C. (4647, 0)
# --------------------------------------------------------------------
# Subtree, depth = 5 (4647 data points).
# Split on feature grade_E. (4647, 0)
# --------------------------------------------------------------------
# Subtree, depth = 6 (4647 data points).
# Reached maximum depth. Stopping for now.
# --------------------------------------------------------------------
# Subtree, depth = 6 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 5 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 4 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 3 (0 data points).
# Stopping condition 1 reached.
# --------------------------------------------------------------------
# Subtree, depth = 0 (37040 data points).
# Early stopping condition 2 reached. Reached minimum node size.

# %% [markdown]
# Now, let us evaluate the models (**model_7**, **model_8**, or **model_9**) on the **validation_set**.

# %%
# YOUR CODE HERE
print("Validation data, classification error (model 7):", evaluate_classification_error(model_7, validation_data, target))
print("Validation data, classification error (model 8):", evaluate_classification_error(model_8, validation_data, target))
print("Validation data, classification error (model 9):", evaluate_classification_error(model_9, validation_data, target))
# Out:
# Validation data, classification error (model 7): 0.3827213822894169
# Validation data, classification error (model 8): 0.3827213822894169
# Validation data, classification error (model 9): 0.5029157667386609

# %% [markdown]
# Using the `count_leaves` function, compute the number of leaves in each of each models (**model_7**, **model_8**, and

# %%
print("Complexity (model 7):", count_leaves(model_7))
print("Complexity (model 8):", count_leaves(model_8))
print("Complexity (model 9):", count_leaves(model_9))
# Out:
# Complexity (model 7): 43
# Complexity (model 8): 43
# Complexity (model 9): 1
